# %% [markdown]
# <a href="https://colab.research.google.com/github/liuerick/tarea1/blob/main/problema1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# lista desde el -30 al 50
lista_numeros = range (-30, 50)
print(lista_numeros)

for x in range(-30,51):
  if(x < 0):
    print(x, "Muy frio")
  elif(x >= 0 and x <= 24):
    print(x, "Templado")
  else:
    print(x, "Caluroso")
# Out:
# range(-30, 50)
# -30 Muy frio
# -29 Muy frio
# -28 Muy frio
# -27 Muy frio
# -26 Muy frio
# -25 Muy frio
# -24 Muy frio
# -23 Muy frio
# -22 Muy frio
# -21 Muy frio
# -20 Muy frio
# -19 Muy frio
# -18 Muy frio
# -17 Muy frio
# -16 Muy frio
# -15 Muy frio
# -14 Muy frio
# -13 Muy frio
# -12 Muy frio
# -11 Muy frio
# -10 Muy frio
# -9 Muy frio
# -8 Muy frio
# -7 Muy frio
# -6 Muy frio
# -5 Muy frio
# -4 Muy frio
# -3 Muy frio
# -2 Muy frio
# -1 Muy frio
# 0 Templado
# 1 Templado
# 2 Templado
# 3 Templado
# 4 Templado
# 5 Templado
# 6 Templado
# 7 Templado
# 8 Templado
# 9 Templado
# 10 Templado
# 11 Templado
# 12 Templado
# 13 Templado
# 14 Templado
# 15 Templado
# 16 Templado
# 17 Templado
# 18 Templado
# 19 Templado
# 20 Templado
# 21 Templado
# 22 Templado
# 23 Templado
# 24 Templado
# 25 Caluroso
# 26 Caluroso
# 27 Caluroso
# 28 Caluroso
# 29 Caluroso
# 30 Caluroso
# 31 Caluroso
# 32 Caluroso
# 33 Caluroso
# 34 Caluroso
# 35 Caluroso
# 36 Caluroso
# 37 Caluroso
# 38 Caluroso
# ...
